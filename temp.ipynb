# %%
import pandas as pd

review_df = pd.read_csv('../data/naver_movie_review_ing.csv')
review_df.head(10)
# Out:
#    Unnamed: 0        id                                           document  \
# 0           0   9976970                                아 더빙.. 진짜 짜증나네요 목소리
# 1           1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2           2  10265843                                  너무재밓었다그래서보는것을추천한다
# 3           3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4           4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...
# 5           5   5403919      막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.
# 6           6   7797314                              원작의 긴장감을 제대로 살려내지못했다.
# 7           7   9443947  별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단...
# 8           8   7156791                             액션이 없는데도 재미 있는 몇안되는 영화
# 9           9   5912145      왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?
#
#    label                                       clean_review  \
# 0      0                                 아 더빙  진짜 짜증나네요 목소리
# ...

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191265 entries, 0 to 191264
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    191265 non-null  int64
#  1   id            191265 non-null  int64
#  2   document      191265 non-null  object
#  3   label         191265 non-null  int64
#  4   clean_review  191265 non-null  object
#  5   tokens        191265 non-null  object
#  6   tokens_str    191265 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 10.2+ MB
